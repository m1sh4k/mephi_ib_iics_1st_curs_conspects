# %%
from math import log
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(-1, 10, 100)  # x values from 1 to 16
y = 2**x

fig, ax = plt.subplots()
ax.plot(x, y)
#ax.set_xscale('log', base=2)  # set x-axis to log base 2
ax.axis('off')  # hide axes
plt.savefig('2__x.svg')
plt.show()
